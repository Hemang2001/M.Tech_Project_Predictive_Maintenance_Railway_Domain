# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemang2001/M.Tech_Project_Predictive_Maintenance_Railway_Domain/blob/main/Code/Dataset%20Load%20%26%20Visualize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project start-up phase 1 - Reading of Datasets

# %% [markdown]
# ####Simple Method to load dataset Manually

# %%
import os

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-913fe336-ceea-421e-80ea-5f68286e3e23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-913fe336-ceea-421e-80ea-5f68286e3e23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# %% [markdown]
# ###Datasets Loading and Visualizing practice for Track Fault Detection from Kaggle Hub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("salmaneunus/railway-track-fault-detection")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.00G/2.00G [01:47<00:00, 20.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2

# %%
DATASET_PATH = "/root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2"

# %%
for root, dirs, files in os.walk(DATASET_PATH):
    print("Folder:", root)
    print("Subfolders:", dirs)
    print("Files:", len(files))
    print("-" * 50)
# Out:
# Folder: /root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2
# Subfolders: ['Railway Track fault Detection Updated']
# Files: 0
# --------------------------------------------------
# Folder: /root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2/Railway Track fault Detection Updated
# Subfolders: ['Train', 'Test', 'Validation']
# Files: 0
# --------------------------------------------------
# Folder: /root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2/Railway Track fault Detection Updated/Train
# Subfolders: ['Non defective', 'Defective']
# Files: 0
# --------------------------------------------------
# Folder: /root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2/Railway Track fault Detection Updated/Train/Non defective
# Subfolders: []
# Files: 150
# --------------------------------------------------
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import random

def visualize_images(dataset_path, num_images=6):
    image_paths = []

    # collect all images
    for root, dirs, files in os.walk(dataset_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.png', '.jpeg')):
                image_paths.append(os.path.join(root, file))

    print("Total Images Found:", len(image_paths))

    # pick random images
    samples = random.sample(image_paths, min(num_images, len(image_paths)))

    plt.figure(figsize=(12, 8))

    for i, img_path in enumerate(samples):
        img = cv2.imread(img_path)

        if img is None:
            print("Corrupted:", img_path)
            continue

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # label from folder
        label = img_path.split("/")[-2]

        plt.subplot(2, 3, i + 1)
        plt.imshow(img)
        plt.title(label)
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# Run
visualize_images(DATASET_PATH)
# Out:
# Total Images Found: 383

# %%
import os

path = "/root/.cache/kagglehub/datasets/salmaneunus/railway-track-fault-detection/versions/2/Railway Track fault Detection Updated/Train/Non defective"

imgs = os.listdir(path)[20:25]

for i, img in enumerate(imgs):
    plt.subplot(2,3,i+1)
    plt.imshow(cv2.cvtColor(cv2.imread(os.path.join(path,img)), cv2.COLOR_BGR2RGB))
    plt.title("Non Defective")
    plt.axis('off')

plt.show()
